# %% [markdown]
# Модуль для анализа пролонгации проектов и создания отчетов.
#
# Этот модуль предоставляет функциональность для:
# - Загрузки и обработки данных о пролонгации проектов
# - Расчета коэффициентов пролонгации на 1 и 2 месяца
# - Создания визуализаций и Excel-отчета с результатами анализа

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from openpyxl.styles import Font, Alignment, Border, Side, PatternFill
from openpyxl.formatting.rule import ColorScaleRule
from google.colab import files
import io

# %% [markdown]
# Загружает и объединяет данные о пролонгации и финансовых показателях.
#
#     Алгоритм обработки:
#     1. Загрузка данных:
#        - Чтение CSV файлов с данными о пролонгации и финансовых показателях
#        - Проверка наличия необходимых колонок (id, month, AM)
#
#     2. Объединение данных:
#        - Слияние таблиц по полю 'id' с использованием left join
#        - Сохранение всех записей из таблицы пролонгаций
#
#     3. Определение месячных колонок:
#        - Поиск колонок, содержащих годы 2022, 2023, 2024
#        - Проверка наличия хотя бы одной месячной колонки
#
#     Args:
#         prolongations_path (str): Путь к файлу с данными о пролонгации
#         financial_path (str): Путь к файлу с финансовыми данными
#
#     Returns:
#         tuple: (pd.DataFrame, list) - объединенные данные и список месячных колонок

# %%
def load_and_process_data(prolongations_path, financial_path):
    try:
        prolongations = pd.read_csv(prolongations_path, encoding='utf-8')
        financial_data = pd.read_csv(financial_path, encoding='utf-8')

        print("\nИнформация о данных:")
        print(f"Количество строк в prolongations.csv: {len(prolongations)}")
        print(f"Количество строк в financial_data.csv: {len(financial_data)}")
        print("\nУникальные значения в колонке 'month':")
        print(prolongations['month'].unique())

        # Проверка необходимых столбцов
        if not all(col in prolongations.columns for col in ['id', 'month', 'AM']):
            print("Ошибка: В prolongations.csv отсутствуют необходимые столбцы")
            return None, None

        # Объединение данных
        data = pd.merge(prolongations, financial_data, on='id', how='left')
        print(f"\nКоличество строк после объединения: {len(data)}")

        # Определение месячных колонок
        month_cols = [col for col in data.columns if any(year in col for year in ['2022', '2023', '2024'])]
        if not month_cols:
            print("❌ Не найдены колонки с месяцами!")
            return None, None

        print("\nНайденные месячные колонки:")
        print(month_cols)

        return data, month_cols
    except Exception as e:
        print(f"Ошибка при загрузке данных: {str(e)}")
        return None, None

# %% [markdown]
# Рассчитывает коэффициенты пролонгации для каждого менеджера по месяцам.
#
#     Алгоритм расчета:
#     1. Коэффициент пролонгации на 1 месяц (1m):
#        - Находит проекты, завершившиеся в предыдущем месяце
#        - Исключает проекты со статусом 'стоп' или 'end'
#        - Для каждого менеджера:
#          * Суммирует отгрузки за последний месяц реализации проектов
#          * Суммирует отгрузки за текущий месяц
#          * Рассчитывает коэффициент как отношение: текущая_отгрузка / последняя_отгрузка
#
#     2. Коэффициент пролонгации на 2 месяца (2m):
#        - Находит проекты, завершившиеся два месяца назад
#        - Исключает проекты со статусом 'стоп' или 'end'
#        - Для каждого менеджера:
#          * Отбирает проекты, которые не были пролонгированы в первый месяц
#          * Суммирует отгрузки за последний месяц реализации этих проектов
#          * Суммирует отгрузки за текущий месяц
#          * Рассчитывает коэффициент как отношение: текущая_отгрузка / последняя_отгрузка
#
#     Особенности:
#     - Все числовые значения проходят через функцию safe_float_convert для корректной обработки
#     - Если знаменатель равен 0, коэффициент принимается равным 0
#     - Результаты округляются до 2 знаков после запятой
#
#     Args:
#         data (pd.DataFrame): Объединенные данные
#         month_cols (list): Список колонок с месяцами
#
#     Returns:
#         pd.DataFrame: Результаты расчета коэффициентов со следующими колонками:
#             - Месяц: текущий месяц анализа
#             - Менеджер: имя менеджера
#             - Коэф. пролонгации (1m): коэффициент на 1 месяц
#             - Коэф. пролонгации (2m): коэффициент на 2 месяца
#             - Отгрузка последнего месяца: сумма отгрузок в последний месяц
#             - Отгрузка текущего месяца: сумма отгрузок в текущий месяц

# %%
def calculate_prolongation_coefficients(data, month_cols):

    results = []

    print(f"\nНачинаем расчет коэффициентов. Всего месяцев: {len(month_cols)}")
    print(f"Месяцы для анализа: {month_cols}")

    # Для каждого месяца (кроме первого)
    for i in range(1, len(month_cols)):
        current_month = month_cols[i]
        prev_month = month_cols[i-1]
        prev_prev_month = month_cols[i-2] if i > 1 else None

        print(f"\nАнализ месяца {current_month}")
        print(f"Предыдущий месяц: {prev_month}")
        print(f"Пред-предыдущий месяц: {prev_prev_month}")

        # Получаем проекты, завершившиеся в предыдущем месяце
        completed_projects = data[
            (data['month'].str.strip().str.lower() == prev_month.lower()) |
            (data['month'].str.strip().str.lower().str.contains(prev_month.lower()))
        ].copy()

        print(f"Найдено проектов, завершившихся в {prev_month}: {len(completed_projects)}")
        if not completed_projects.empty:
            print("Примеры значений в колонке 'month':")
            print(completed_projects['month'].head())

        if completed_projects.empty:
            print(f"Пропускаем {current_month} - нет завершенных проектов в {prev_month}")
            continue

        # Исключаем проекты со 'стоп' или 'end'
        completed_projects = completed_projects[
            ~completed_projects[current_month].str.lower().isin(['стоп', 'end'])
        ]
        print(f"Проектов после исключения 'стоп' и 'end': {len(completed_projects)}")

        # Группируем по менеджерам
        managers = completed_projects['AM'].unique()
        print(f"Найдено менеджеров: {len(managers)}")

        for manager in managers:
            print(f"\nОбработка менеджера: {manager}")
            manager_projects = completed_projects[completed_projects['AM'] == manager]
            print(f"Проектов у менеджера: {len(manager_projects)}")

            try:
                def safe_float_convert(x):
                    """Преобразует строковое значение в число с учетом специальных случаев."""
                    if pd.isna(x) or str(x).strip() == '':
                        return 0.0
                    x_str = str(x).replace('\xa0', '').replace(' ', '')
                    if x_str.lower() == 'в ноль':
                        return 0.0
                    try:
                        # Извлекаем только цифры, точки и минусы
                        clean_num = ''.join(c for c in x_str if c.isdigit() or c in '.-')
                        return float(clean_num) if clean_num else 0.0
                    except:
                        return 0.0

                # Расчет коэффициента пролонгации на 1 месяц
                last_month_shipment = manager_projects[prev_month].apply(safe_float_convert).sum()
                current_month_shipment = manager_projects[current_month].apply(safe_float_convert).sum()

                print(f"Отгрузка за {prev_month}: {last_month_shipment}")
                print(f"Отгрузка за {current_month}: {current_month_shipment}")

                coef_1m = current_month_shipment / last_month_shipment if last_month_shipment > 0 else 0
                print(f"Коэффициент пролонгации 1m: {coef_1m}")

                # Расчет коэффициента пролонгации на 2 месяца
                coef_2m = 0
                if prev_prev_month:
                    # Проекты, завершившиеся два месяца назад
                    prev_completed = data[
                        (data['month'].str.strip().str.lower() == prev_prev_month.lower()) |
                        (data['month'].str.strip().str.lower().str.contains(prev_prev_month.lower()))
                    ].copy()

                    prev_completed = prev_completed[prev_completed['AM'] == manager]
                    print(f"Проектов, завершившихся в {prev_prev_month}: {len(prev_completed)}")

                    # Исключаем проекты со 'стоп' или 'end'
                    prev_completed = prev_completed[
                        ~prev_completed[current_month].str.lower().isin(['стоп', 'end'])
                    ]

                    # Находим проекты, которые не были пролонгированы в первый месяц
                    no_first_month_prolongation = prev_completed[
                        prev_completed[prev_month].apply(
                            lambda x: safe_float_convert(x) == 0
                        )
                    ]

                    print(f"Проектов без пролонгации в первый месяц: {len(no_first_month_prolongation)}")

                    if not no_first_month_prolongation.empty:
                        # Сумма отгрузки в последний месяц реализации
                        last_month_shipment_2m = no_first_month_prolongation[prev_prev_month].apply(safe_float_convert).sum()

                        # Сумма отгрузки в текущий месяц
                        current_month_shipment_2m = no_first_month_prolongation[current_month].apply(safe_float_convert).sum()

                        print(f"Отгрузка за {prev_prev_month} (для 2m): {last_month_shipment_2m}")
                        print(f"Отгрузка за {current_month} (для 2m): {current_month_shipment_2m}")

                        coef_2m = current_month_shipment_2m / last_month_shipment_2m if last_month_shipment_2m > 0 else 0
                        print(f"Коэффициент пролонгации 2m: {coef_2m}")

                results.append({
                    'Месяц': current_month,
                    'Менеджер': manager,
                    'Коэф. пролонгации (1m)': round(coef_1m, 2),
                    'Коэф. пролонгации (2m)': round(coef_2m, 2),
                    'Отгрузка последнего месяца': last_month_shipment,
                    'Отгрузка текущего месяца': current_month_shipment
                })

            except Exception as e:
                print(f"Ошибка при обработке менеджера {manager}: {str(e)}")
                continue

    if not results:
        print("Не удалось рассчитать ни одного коэффициента")
        return pd.DataFrame()

    return pd.DataFrame(results)

# %% [markdown]
# Создает визуализации и добавляет их в Excel-файл.
#
#     Args:
#         data (pd.DataFrame): Данные для визуализации
#         writer (pd.ExcelWriter): Объект для записи в Excel
#
#     Returns:
#         bool: True если визуализации успешно созданы, False в случае ошибки

# %%
def create_visualizations(data, writer):
    try:
        print("Начинаем создание визуализаций...")

        # Настройка стиля графиков
        plt.style.use('default')
        plt.rcParams.update({
            'figure.facecolor': 'white',
            'axes.facecolor': 'white',
            'axes.grid': True,
            'grid.alpha': 0.3,
            'axes.labelsize': 12,
            'axes.titlesize': 14,
            'xtick.labelsize': 10,
            'ytick.labelsize': 10
        })

        # Создаем фигуру с несколькими графиками
        fig = plt.figure(figsize=(20, 15))

        # 1. График средних коэффициентов пролонгации по месяцам
        plt.subplot(2, 2, 1)
        monthly_avg = data.groupby('Месяц')[['Коэф. пролонгации (1m)', 'Коэф. пролонгации (2m)']].mean()
        monthly_avg.plot(kind='bar', ax=plt.gca())
        plt.title('Средние коэффициенты пролонгации по месяцам')
        plt.xlabel('Месяц')
        plt.ylabel('Коэффициент')
        plt.xticks(rotation=45)
        plt.legend(['1 месяц', '2 месяца'])
        plt.grid(True, alpha=0.3)

        # 2. График отгрузок по месяцам
        plt.subplot(2, 2, 2)
        monthly_shipments = data.groupby('Месяц')[['Отгрузка последнего месяца', 'Отгрузка текущего месяца']].sum()
        monthly_shipments.plot(kind='bar', ax=plt.gca())
        plt.title('Сумма отгрузок по месяцам')
        plt.xlabel('Месяц')
        plt.ylabel('Сумма отгрузки')
        plt.xticks(rotation=45)
        plt.legend(['Последний месяц', 'Текущий месяц'])
        plt.grid(True, alpha=0.3)

        # 3. Тепловая карта коэффициентов по менеджерам и месяцам
        plt.subplot(2, 2, 3)
        pivot_1m = data.pivot_table(
            values='Коэф. пролонгации (1m)',
            index='Менеджер',
            columns='Месяц',
            aggfunc='mean'
        )
        sns.heatmap(pivot_1m, annot=True, cmap='RdYlGn', center=1, fmt='.2f')
        plt.title('Коэффициенты пролонгации (1m) по менеджерам')
        plt.xticks(rotation=45)

        # 4. Тепловая карта коэффициентов 2m
        plt.subplot(2, 2, 4)
        pivot_2m = data.pivot_table(
            values='Коэф. пролонгации (2m)',
            index='Менеджер',
            columns='Месяц',
            aggfunc='mean'
        )
        sns.heatmap(pivot_2m, annot=True, cmap='RdYlGn', center=1, fmt='.2f')
        plt.title('Коэффициенты пролонгации (2m) по менеджерам')
        plt.xticks(rotation=45)

        # Настройка общего вида
        plt.tight_layout()

        # Сохраняем график в BytesIO
        img_data = io.BytesIO()
        plt.savefig(img_data, format='png', dpi=300, bbox_inches='tight')
        img_data.seek(0)

        print("Графики созданы, сохраняем в Excel...")

        # Создаем лист для графиков
        worksheet = writer.book.create_sheet('Графики')
        print("Лист 'Графики' создан")

        # Добавляем изображение напрямую из BytesIO
        from openpyxl.drawing.image import Image
        img = Image(img_data)
        worksheet.add_image(img, 'A1')
        print("Изображение добавлено на лист")

        # Настраиваем размеры ячеек
        worksheet.column_dimensions['A'].width = 100
        worksheet.row_dimensions[1].height = 75
        print("Размеры ячеек настроены")

        plt.close()
        return True

    except Exception as e:
        print(f"Ошибка при создании визуализаций: {str(e)}")
        import traceback
        print(traceback.format_exc())
        return False

# %% [markdown]
# Генерирует и сохраняет отчет в Excel-файл.
#
#     Args:
#         data (pd.DataFrame): Данные для отчета
#         output_file (str): Путь к файлу для сохранения отчета
#
#     Returns:
#         bool: True если отчет успешно создан, False в случае ошибки

# %%
def generate_and_save_report(data, output_file):
    if data is None or data.empty:
        print("Нет данных для отчета")
        return False

    try:
        print("Начинаем создание отчета...")

        # Создаем Excel writer
        with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
            print("Excel writer создан")

            # Создаем визуализации до сохранения данных
            print("Создаем визуализации...")
            create_visualizations(data, writer)

            # Сохраняем основной отчет
            print("Сохраняем основной отчет...")
            data.to_excel(writer, sheet_name='Отчет по месяцам', index=False)

            # Создаем сводный отчет по менеджерам
            print("Создаем сводный отчет...")
            manager_summary = data.groupby('Менеджер').agg({
                'Коэф. пролонгации (1m)': 'mean',
                'Коэф. пролонгации (2m)': 'mean',
                'Отгрузка последнего месяца': 'sum',
                'Отгрузка текущего месяца': 'sum'
            }).round(2)

            # Переименовываем столбцы
            manager_summary = manager_summary.rename(columns={
                'Отгрузка последнего месяца': 'Общая сумма отгрузок завершенных проектов',
                'Отгрузка текущего месяца': 'Общая сумма отгрузок пролонгированных проектов'
            })

            # Добавляем итоговую строку в сводный отчет
            total_row = pd.DataFrame({
                'Менеджер': ['ИТОГО'],
                'Коэф. пролонгации (1m)': [manager_summary['Коэф. пролонгации (1m)'].mean()],
                'Коэф. пролонгации (2m)': [manager_summary['Коэф. пролонгации (2m)'].mean()],
                'Общая сумма отгрузок завершенных проектов': [manager_summary['Общая сумма отгрузок завершенных проектов'].sum()],
                'Общая сумма отгрузок пролонгированных проектов': [manager_summary['Общая сумма отгрузок пролонгированных проектов'].sum()]
            })

            # Объединяем сводный отчет с итоговой строкой
            manager_summary = pd.concat([manager_summary.reset_index(), total_row], ignore_index=True)
            manager_summary.to_excel(writer, sheet_name='Сводный отчет', index=False)

            # Форматирование
            print("Применяем форматирование...")
            for sheet_name in writer.sheets:
                worksheet = writer.sheets[sheet_name]

                # Стили для заголовков
                header_font = Font(bold=True, size=11, color="FFFFFF")
                header_fill = PatternFill(start_color="4472C4", end_color="4472C4", fill_type="solid")
                header_alignment = Alignment(horizontal='center', vertical='center', wrap_text=True)

                # Стили для данных
                data_font = Font(size=10)
                data_alignment = Alignment(horizontal='right', vertical='center')
                data_alignment_text = Alignment(horizontal='left', vertical='center')

                # Стили для границ
                thin_border = Border(
                    left=Side(style='thin'),
                    right=Side(style='thin'),
                    top=Side(style='thin'),
                    bottom=Side(style='thin')
                )

                # Форматирование заголовков
                for cell in worksheet[1]:
                    cell.font = header_font
                    cell.fill = header_fill
                    cell.alignment = header_alignment
                    cell.border = thin_border

                # Форматирование данных
                for row in worksheet.iter_rows(min_row=2):
                    for cell in row:
                        cell.border = thin_border
                        cell.font = data_font

                        # Форматирование в зависимости от типа данных
                        if cell.column in [1, 2]:  # Месяц/Менеджер
                            cell.alignment = data_alignment_text
                        else:  # Числовые данные
                            cell.alignment = data_alignment
                            if cell.column in [3, 4]:  # Коэффициенты
                                cell.number_format = '0.00'
                            else:  # Отгрузки
                                cell.number_format = '#,##0'

                # Автоподбор ширины столбцов
                for column in worksheet.columns:
                    max_length = 0
                    column_letter = column[0].column_letter

                    for cell in column:
                        try:
                            if len(str(cell.value)) > max_length:
                                max_length = len(str(cell.value))
                        except:
                            pass

                    adjusted_width = (max_length + 2) * 1.2
                    worksheet.column_dimensions[column_letter].width = adjusted_width

                # Замораживаем заголовки
                worksheet.freeze_panes = 'A2'

                # Добавляем условное форматирование для коэффициентов
                if sheet_name == 'Отчет по месяцам':
                    # Цветовая шкала для коэффициентов
                    worksheet.conditional_formatting.add(
                        f'C2:C{len(data)+1}',
                        ColorScaleRule(
                            start_type='num', start_value=0, start_color='FF0000',
                            mid_type='num', mid_value=1, mid_color='FFFFFF',
                            end_type='num', end_value=2, end_color='00FF00'
                        )
                    )
                    worksheet.conditional_formatting.add(
                        f'D2:D{len(data)+1}',
                        ColorScaleRule(
                            start_type='num', start_value=0, start_color='FF0000',
                            mid_type='num', mid_value=1, mid_color='FFFFFF',
                            end_type='num', end_value=2, end_color='00FF00'
                        )
                    )

                # Форматирование итоговой строки в сводном отчете
                if sheet_name == 'Сводный отчет':
                    last_row = len(manager_summary) + 1
                    for cell in worksheet[last_row]:
                        cell.font = Font(bold=True)
                        cell.border = thin_border
                        if cell.column > 1:  # Для числовых столбцов
                            cell.alignment = data_alignment
                            cell.number_format = '#,##0' if cell.column > 4 else '0.00'

        print(f"Отчет сохранен как {output_file}")
        files.download(output_file)
        return True

    except Exception as e:
        print(f"Ошибка при сохранении отчета: {str(e)}")
        import traceback
        print(traceback.format_exc())
        return False

# %% [markdown]
# Вызов программы

# %%
if __name__ == "__main__":
    prolongations_file = 'prolongations.csv'
    financial_file = 'financial_data.csv'
    output_file = 'отчет_пролонгации.xlsx'

    # Загрузка и обработка данных
    data, month_cols = load_and_process_data(prolongations_file, financial_file)

    if data is not None and month_cols is not None:
        # Расчет коэффициентов
        results = calculate_prolongation_coefficients(data, month_cols)

        if not results.empty:
            print("\nРезультаты расчета:")
            print(results.head())

            # Генерация и сохранение отчета
            generate_and_save_report(results, output_file)
        else:
            print("Не удалось рассчитать коэффициенты")
    else:
        print("Не удалось загрузить данные")
# Out:
# Информация о данных:
# Количество строк в prolongations.csv: 477
# Количество строк в financial_data.csv: 451
#
# Уникальные значения в колонке 'month':
# ['ноябрь 2022' 'декабрь 2022' 'январь 2023' 'февраль 2023' 'март 2023'
#  'апрель 2023' 'май 2023' 'июнь 2023' 'июль 2023' 'август 2023'
#  'сентябрь 2023' 'октябрь 2023' 'ноябрь 2023' 'декабрь 2023']
#
# Количество строк после объединения: 725
#
# Найденные месячные колонки:
# ['Ноябрь 2022', 'Декабрь 2022', 'Январь 2023', 'Февраль 2023', 'Март 2023', 'Апрель 2023', 'Май 2023', 'Июнь 2023', 'Июль 2023', 'Август 2023', 'Сентябрь 2023', 'Октябрь 2023', 'Ноябрь 2023', 'Декабрь 2023', 'Январь 2024', 'Февраль 2024']
#
# Начинаем расчет коэффициентов. Всего месяцев: 16
# Месяцы для анализа: ['Ноябрь 2022', 'Декабрь 2022', 'Январь 2023', 'Февраль 2023', 'Март 2023', 'Апрель 2023', 'Май 2023', 'Июнь 2023', 'Июль 2023', 'Август 2023', 'Сентябрь 2023', 'Октябрь 2023', 'Ноябрь 2023', 'Декабрь 2023', 'Январь 2024', 'Февраль 2024']
#
# Анализ месяца Декабрь 2022
# Предыдущий месяц: Ноябрь 2022
# Пред-предыдущий месяц: None
# Найдено проектов, завершившихся в Ноябрь 2022: 33
# Примеры значений в колонке 'month':
# 0    ноябрь 2022
# 1    ноябрь 2022
# 2    ноябрь 2022
# 3    ноябрь 2022
# 4    ноябрь 2022
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 33
# Найдено менеджеров: 5
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 16
# Отгрузка за Ноябрь 2022: 62507900.0
# Отгрузка за Декабрь 2022: 26199500.0
# Коэффициент пролонгации 1m: 0.4191390208277674
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 6
# Отгрузка за Ноябрь 2022: 85920500.0
# Отгрузка за Декабрь 2022: 77866000.0
# Коэффициент пролонгации 1m: 0.9062563648954557
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 7
# Отгрузка за Ноябрь 2022: 22443500.0
# Отгрузка за Декабрь 2022: 18752000.0
# Коэффициент пролонгации 1m: 0.8355203065475527
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 1
# Отгрузка за Ноябрь 2022: 5224000.0
# Отгрузка за Декабрь 2022: 0.0
# Коэффициент пролонгации 1m: 0.0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 3
# Отгрузка за Ноябрь 2022: 13802000.0
# Отгрузка за Декабрь 2022: 4083000.0
# Коэффициент пролонгации 1m: 0.29582669178379944
#
# Анализ месяца Январь 2023
# Предыдущий месяц: Декабрь 2022
# Пред-предыдущий месяц: Ноябрь 2022
# Найдено проектов, завершившихся в Декабрь 2022: 89
# Примеры значений в колонке 'month':
# 33    декабрь 2022
# 34    декабрь 2022
# 35    декабрь 2022
# 36    декабрь 2022
# 37    декабрь 2022
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 89
# Найдено менеджеров: 7
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 20
# Отгрузка за Декабрь 2022: 229659571.0
# Отгрузка за Январь 2023: 62023192.0
# Коэффициент пролонгации 1m: 0.2700657835853921
# Проектов, завершившихся в Ноябрь 2022: 1
# Проектов без пролонгации в первый месяц: 1
# Отгрузка за Ноябрь 2022 (для 2m): 5224000.0
# Отгрузка за Январь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 27
# Отгрузка за Декабрь 2022: 169309768.0
# Отгрузка за Январь 2023: 94176160.0
# Коэффициент пролонгации 1m: 0.556235833953774
# Проектов, завершившихся в Ноябрь 2022: 16
# Проектов без пролонгации в первый месяц: 11
# Отгрузка за Ноябрь 2022 (для 2m): 26086200.0
# Отгрузка за Январь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 13
# Отгрузка за Декабрь 2022: 91151326.0
# Отгрузка за Январь 2023: 38951900.0
# Коэффициент пролонгации 1m: 0.4273322365052594
# Проектов, завершившихся в Ноябрь 2022: 7
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Ноябрь 2022 (для 2m): 10809500.0
# Отгрузка за Январь 2023 (для 2m): 7677500.0
# Коэффициент пролонгации 2m: 0.7102548684027938
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 6
# Отгрузка за Декабрь 2022: 15007500.0
# Отгрузка за Январь 2023: 11156500.0
# Коэффициент пролонгации 1m: 0.7433949691820756
# Проектов, завершившихся в Ноябрь 2022: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 12
# Отгрузка за Декабрь 2022: 64108021.0
# Отгрузка за Январь 2023: 44101409.0
# Коэффициент пролонгации 1m: 0.6879234191303456
# Проектов, завершившихся в Ноябрь 2022: 6
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Ноябрь 2022 (для 2m): 4102500.0
# Отгрузка за Январь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 9
# Отгрузка за Декабрь 2022: 24207000.0
# Отгрузка за Январь 2023: 10667500.0
# Коэффициент пролонгации 1m: 0.44067831618953196
# Проектов, завершившихся в Ноябрь 2022: 3
# Проектов без пролонгации в первый месяц: 2
# Отгрузка за Ноябрь 2022 (для 2m): 8280000.0
# Отгрузка за Январь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 2
# Отгрузка за Декабрь 2022: 5233500.0
# Отгрузка за Январь 2023: 6625500.0
# Коэффициент пролонгации 1m: 1.2659787904843796
# Проектов, завершившихся в Ноябрь 2022: 0
# Проектов без пролонгации в первый месяц: 0
#
# Анализ месяца Февраль 2023
# Предыдущий месяц: Январь 2023
# Пред-предыдущий месяц: Декабрь 2022
# Найдено проектов, завершившихся в Январь 2023: 36
# Примеры значений в колонке 'month':
# 122    январь 2023
# 123    январь 2023
# 124    январь 2023
# 125    январь 2023
# 126    январь 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 36
# Найдено менеджеров: 6
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 7
# Отгрузка за Январь 2023: 75622500.0
# Отгрузка за Февраль 2023: 87401500.0
# Коэффициент пролонгации 1m: 1.155760521008959
# Проектов, завершившихся в Декабрь 2022: 27
# Проектов без пролонгации в первый месяц: 21
# Отгрузка за Декабрь 2022 (для 2m): 89133500.0
# Отгрузка за Февраль 2023 (для 2m): 17577500.0
# Коэффициент пролонгации 2m: 0.19720419370943584
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 2
# Отгрузка за Январь 2023: 90042000.0
# Отгрузка за Февраль 2023: 81366000.0
# Коэффициент пролонгации 1m: 0.9036449656826814
# Проектов, завершившихся в Декабрь 2022: 12
# Проектов без пролонгации в первый месяц: 6
# Отгрузка за Декабрь 2022 (для 2m): 14714000.0
# Отгрузка за Февраль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 2
# Отгрузка за Январь 2023: 4800000.0
# Отгрузка за Февраль 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Декабрь 2022: 6
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Декабрь 2022 (для 2m): 3829500.0
# Отгрузка за Февраль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 7
# Отгрузка за Январь 2023: 19387700.0
# Отгрузка за Февраль 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Декабрь 2022: 9
# Проектов без пролонгации в первый месяц: 6
# Отгрузка за Декабрь 2022 (для 2m): 13712500.0
# Отгрузка за Февраль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 14
# Отгрузка за Январь 2023: 58429850.0
# Отгрузка за Февраль 2023: 13715500.0
# Коэффициент пролонгации 1m: 0.2347344721918677
# Проектов, завершившихся в Декабрь 2022: 13
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Декабрь 2022 (для 2m): 44671276.0
# Отгрузка за Февраль 2023 (для 2m): 9634500.0
# Коэффициент пролонгации 2m: 0.21567550476955258
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 4
# Отгрузка за Январь 2023: 6625500.0
# Отгрузка за Февраль 2023: 5611500.0
# Коэффициент пролонгации 1m: 0.8469549467964682
# Проектов, завершившихся в Декабрь 2022: 2
# Проектов без пролонгации в первый месяц: 0
#
# Анализ месяца Март 2023
# Предыдущий месяц: Февраль 2023
# Пред-предыдущий месяц: Январь 2023
# Найдено проектов, завершившихся в Февраль 2023: 44
# Примеры значений в колонке 'month':
# 158    февраль 2023
# 159    февраль 2023
# 160    февраль 2023
# 161    февраль 2023
# 162    февраль 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 44
# Найдено менеджеров: 6
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 12
# Отгрузка за Февраль 2023: 99146742.0
# Отгрузка за Март 2023: 62189755.0
# Коэффициент пролонгации 1m: 0.6272496074555833
# Проектов, завершившихся в Январь 2023: 7
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Январь 2023 (для 2m): 9575000.0
# Отгрузка за Март 2023 (для 2m): 14277408.0
# Коэффициент пролонгации 2m: 1.4911131070496084
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 13
# Отгрузка за Февраль 2023: 38286500.0
# Отгрузка за Март 2023: 26208000.0
# Коэффициент пролонгации 1m: 0.6845232653807478
# Проектов, завершившихся в Январь 2023: 7
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Январь 2023 (для 2m): 19387700.0
# Отгрузка за Март 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 11
# Отгрузка за Февраль 2023: 29006000.0
# Отгрузка за Март 2023: 27243000.0
# Коэффициент пролонгации 1m: 0.9392194718334138
# Проектов, завершившихся в Январь 2023: 14
# Проектов без пролонгации в первый месяц: 12
# Отгрузка за Январь 2023 (для 2m): 49069850.0
# Отгрузка за Март 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 5
# Отгрузка за Февраль 2023: 22963375.0
# Отгрузка за Март 2023: 10243375.0
# Коэффициент пролонгации 1m: 0.4460744555188425
# Проектов, завершившихся в Январь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 1
# Отгрузка за Февраль 2023: 530660.0
# Отгрузка за Март 2023: 1289810.0
# Коэффициент пролонгации 1m: 2.4305770172992123
# Проектов, завершившихся в Январь 2023: 2
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 2
# Отгрузка за Февраль 2023: 0.0
# Отгрузка за Март 2023: 0.0
# Коэффициент пролонгации 1m: 0
# Проектов, завершившихся в Январь 2023: 4
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Январь 2023 (для 2m): 3312750.0
# Отгрузка за Март 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Анализ месяца Апрель 2023
# Предыдущий месяц: Март 2023
# Пред-предыдущий месяц: Февраль 2023
# Найдено проектов, завершившихся в Март 2023: 48
# Примеры значений в колонке 'month':
# 202    март 2023
# 203    март 2023
# 204    март 2023
# 205    март 2023
# 206    март 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 46
# Найдено менеджеров: 7
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 18
# Отгрузка за Март 2023: 160103335.0
# Отгрузка за Апрель 2023: 56236000.0
# Коэффициент пролонгации 1m: 0.3512481485785415
# Проектов, завершившихся в Февраль 2023: 12
# Проектов без пролонгации в первый месяц: 5
# Отгрузка за Февраль 2023 (для 2m): 36478000.0
# Отгрузка за Апрель 2023 (для 2m): 4020000.0
# Коэффициент пролонгации 2m: 0.11020341027468611
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 2
# Отгрузка за Март 2023: 9307500.0
# Отгрузка за Апрель 2023: 8992000.0
# Коэффициент пролонгации 1m: 0.9661026054257319
# Проектов, завершившихся в Февраль 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 7
# Отгрузка за Март 2023: 33746500.0
# Отгрузка за Апрель 2023: 11107000.0
# Коэффициент пролонгации 1m: 0.3291304283407168
# Проектов, завершившихся в Февраль 2023: 13
# Проектов без пролонгации в первый месяц: 8
# Отгрузка за Февраль 2023 (для 2m): 9292500.0
# Отгрузка за Апрель 2023 (для 2m): 6696500.0
# Коэффициент пролонгации 2m: 0.7206349206349206
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 2
# Отгрузка за Март 2023: 7793710.0
# Отгрузка за Апрель 2023: 8564035.0
# Коэффициент пролонгации 1m: 1.0988393204263438
# Проектов, завершившихся в Февраль 2023: 1
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 6
# Отгрузка за Март 2023: 82197375.0
# Отгрузка за Апрель 2023: 22824800.0
# Коэффициент пролонгации 1m: 0.2776828335454751
# Проектов, завершившихся в Февраль 2023: 5
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Февраль 2023 (для 2m): 12720000.0
# Отгрузка за Апрель 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 10
# Отгрузка за Март 2023: 39845300.0
# Отгрузка за Апрель 2023: 42468500.0
# Коэффициент пролонгации 1m: 1.0658346153749627
# Проектов, завершившихся в Февраль 2023: 11
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Февраль 2023 (для 2m): 4283000.0
# Отгрузка за Апрель 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 1
# Отгрузка за Март 2023: 142500.0
# Отгрузка за Апрель 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Февраль 2023: 2
# Проектов без пролонгации в первый месяц: 2
# Отгрузка за Февраль 2023 (для 2m): 0.0
# Отгрузка за Апрель 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0
#
# Анализ месяца Май 2023
# Предыдущий месяц: Апрель 2023
# Пред-предыдущий месяц: Март 2023
# Найдено проектов, завершившихся в Апрель 2023: 45
# Примеры значений в колонке 'month':
# 250    апрель 2023
# 251    апрель 2023
# 252    апрель 2023
# 253    апрель 2023
# 254    апрель 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 45
# Найдено менеджеров: 5
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 17
# Отгрузка за Апрель 2023: 227772350.0
# Отгрузка за Май 2023: 113182300.0
# Коэффициент пролонгации 1m: 0.49690974343461797
# Проектов, завершившихся в Март 2023: 18
# Проектов без пролонгации в первый месяц: 13
# Отгрузка за Март 2023 (для 2m): 101520335.0
# Отгрузка за Май 2023 (для 2m): 1927730.0
# Коэффициент пролонгации 2m: 0.01898860952340238
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 16
# Отгрузка за Апрель 2023: 46436500.0
# Отгрузка за Май 2023: 35150000.0
# Коэффициент пролонгации 1m: 0.7569476597073422
# Проектов, завершившихся в Март 2023: 9
# Проектов без пролонгации в первый месяц: 6
# Отгрузка за Март 2023 (для 2m): 27366000.0
# Отгрузка за Май 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 3
# Отгрузка за Апрель 2023: 41046000.0
# Отгрузка за Май 2023: 48828975.0
# Коэффициент пролонгации 1m: 1.1896159187253326
# Проектов, завершившихся в Март 2023: 2
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 7
# Отгрузка за Апрель 2023: 35673000.0
# Отгрузка за Май 2023: 8469000.0
# Коэффициент пролонгации 1m: 0.23740644184677487
# Проектов, завершившихся в Март 2023: 10
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Март 2023 (для 2m): 4979500.0
# Отгрузка за Май 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 2
# Отгрузка за Апрель 2023: 13815800.0
# Отгрузка за Май 2023: 13815800.0
# Коэффициент пролонгации 1m: 1.0
# Проектов, завершившихся в Март 2023: 6
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Март 2023 (для 2m): 47874000.0
# Отгрузка за Май 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Анализ месяца Июнь 2023
# Предыдущий месяц: Май 2023
# Пред-предыдущий месяц: Апрель 2023
# Найдено проектов, завершившихся в Май 2023: 32
# Примеры значений в колонке 'month':
# 295    май 2023
# 296    май 2023
# 297    май 2023
# 298    май 2023
# 299    май 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 28
# Найдено менеджеров: 6
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 9
# Отгрузка за Май 2023: 39028600.0
# Отгрузка за Июнь 2023: 15193328.0
# Коэффициент пролонгации 1m: 0.38928703566102807
# Проектов, завершившихся в Апрель 2023: 17
# Проектов без пролонгации в первый месяц: 6
# Отгрузка за Апрель 2023 (для 2m): 67820850.0
# Отгрузка за Июнь 2023 (для 2m): 3863250.0
# Коэффициент пролонгации 2m: 0.0569625712446836
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 4
# Отгрузка за Май 2023: 13439435.0
# Отгрузка за Июнь 2023: 5139500.0
# Коэффициент пролонгации 1m: 0.38241935021821977
# Проектов, завершившихся в Апрель 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 5
# Отгрузка за Май 2023: 7691000.0
# Отгрузка за Июнь 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Апрель 2023: 16
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Апрель 2023 (для 2m): 13705000.0
# Отгрузка за Июнь 2023 (для 2m): 2200000.0
# Коэффициент пролонгации 2m: 0.16052535570959503
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 4
# Отгрузка за Май 2023: 15938500.0
# Отгрузка за Июнь 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Апрель 2023: 2
# Проектов без пролонгации в первый месяц: 1
# Отгрузка за Апрель 2023 (для 2m): 0.0
# Отгрузка за Июнь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 4
# Отгрузка за Май 2023: 16928000.0
# Отгрузка за Июнь 2023: 12974000.0
# Коэффициент пролонгации 1m: 0.7664224952741021
# Проектов, завершившихся в Апрель 2023: 7
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Апрель 2023 (для 2m): 27050000.0
# Отгрузка за Июнь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 2
# Отгрузка за Май 2023: 19692518.0
# Отгрузка за Июнь 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Апрель 2023: 3
# Проектов без пролонгации в первый месяц: 1
# Отгрузка за Апрель 2023 (для 2m): 0.0
# Отгрузка за Июнь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0
#
# Анализ месяца Июль 2023
# Предыдущий месяц: Июнь 2023
# Пред-предыдущий месяц: Май 2023
# Найдено проектов, завершившихся в Июнь 2023: 49
# Примеры значений в колонке 'month':
# 327    июнь 2023
# 328    июнь 2023
# 329    июнь 2023
# 330    июнь 2023
# 331    июнь 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 49
# Найдено менеджеров: 6
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 8
# Отгрузка за Июнь 2023: 42429225.0
# Отгрузка за Июль 2023: 20052500.0
# Коэффициент пролонгации 1m: 0.4726105650056064
# Проектов, завершившихся в Май 2023: 8
# Проектов без пролонгации в первый месяц: 8
# Отгрузка за Май 2023 (для 2m): 30683000.0
# Отгрузка за Июль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 17
# Отгрузка за Июнь 2023: 89175560.0
# Отгрузка за Июль 2023: 52169100.0
# Коэффициент пролонгации 1m: 0.5850156702127802
# Проектов, завершившихся в Май 2023: 9
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Май 2023 (для 2m): 23068600.0
# Отгрузка за Июль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 16
# Отгрузка за Июнь 2023: 87641000.0
# Отгрузка за Июль 2023: 54257500.0
# Коэффициент пролонгации 1m: 0.6190880980363072
# Проектов, завершившихся в Май 2023: 4
# Проектов без пролонгации в первый месяц: 2
# Отгрузка за Май 2023 (для 2m): 7458000.0
# Отгрузка за Июль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 5
# Отгрузка за Июнь 2023: 32066000.0
# Отгрузка за Июль 2023: 3080000.0
# Коэффициент пролонгации 1m: 0.09605189297074783
# Проектов, завершившихся в Май 2023: 5
# Проектов без пролонгации в первый месяц: 5
# Отгрузка за Май 2023 (для 2m): 7691000.0
# Отгрузка за Июль 2023 (для 2m): 3890000.0
# Коэффициент пролонгации 2m: 0.5057859836172149
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 2
# Отгрузка за Июнь 2023: 3368500.0
# Отгрузка за Июль 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Май 2023: 4
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Май 2023 (для 2m): 13439435.0
# Отгрузка за Июль 2023 (для 2m): 6938500.0
# Коэффициент пролонгации 2m: 0.5162791441753318
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 1
# Отгрузка за Июнь 2023: 7918000.0
# Отгрузка за Июль 2023: 9482000.0
# Коэффициент пролонгации 1m: 1.1975246274311695
# Проектов, завершившихся в Май 2023: 2
# Проектов без пролонгации в первый месяц: 2
# Отгрузка за Май 2023 (для 2m): 19692518.0
# Отгрузка за Июль 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Анализ месяца Август 2023
# Предыдущий месяц: Июль 2023
# Пред-предыдущий месяц: Июнь 2023
# Найдено проектов, завершившихся в Июль 2023: 36
# Примеры значений в колонке 'month':
# 376    июль 2023
# 377    июль 2023
# 378    июль 2023
# 379    июль 2023
# 380    июль 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 36
# Найдено менеджеров: 6
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 8
# Отгрузка за Июль 2023: 64900000.0
# Отгрузка за Август 2023: 30990000.0
# Коэффициент пролонгации 1m: 0.47750385208012325
# Проектов, завершившихся в Июнь 2023: 17
# Проектов без пролонгации в первый месяц: 9
# Отгрузка за Июнь 2023 (для 2m): 49360760.0
# Отгрузка за Август 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 9
# Отгрузка за Июль 2023: 30343370.0
# Отгрузка за Август 2023: 16405888.0
# Коэффициент пролонгации 1m: 0.540674552628795
# Проектов, завершившихся в Июнь 2023: 8
# Проектов без пролонгации в первый месяц: 5
# Отгрузка за Июнь 2023 (для 2m): 27078725.0
# Отгрузка за Август 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 7
# Отгрузка за Июль 2023: 46686213.0
# Отгрузка за Август 2023: 25269500.0
# Коэффициент пролонгации 1m: 0.5412625778835392
# Проектов, завершившихся в Июнь 2023: 16
# Проектов без пролонгации в первый месяц: 9
# Отгрузка за Июнь 2023 (для 2m): 42808000.0
# Отгрузка за Август 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 5
# Отгрузка за Июль 2023: 29234000.0
# Отгрузка за Август 2023: 10890500.0
# Коэффициент пролонгации 1m: 0.37252856263255113
# Проектов, завершившихся в Июнь 2023: 2
# Проектов без пролонгации в первый месяц: 2
# Отгрузка за Июнь 2023 (для 2m): 3368500.0
# Отгрузка за Август 2023 (для 2m): 5231500.0
# Коэффициент пролонгации 2m: 1.5530651625352532
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 6
# Отгрузка за Июль 2023: 22528000.0
# Отгрузка за Август 2023: 10812000.0
# Коэффициент пролонгации 1m: 0.47993607954545453
# Проектов, завершившихся в Июнь 2023: 5
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Июнь 2023 (для 2m): 27649500.0
# Отгрузка за Август 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: без А/М
# Проектов у менеджера: 1
# Отгрузка за Июль 2023: 0.0
# Отгрузка за Август 2023: 0.0
# Коэффициент пролонгации 1m: 0
# Проектов, завершившихся в Июнь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Анализ месяца Сентябрь 2023
# Предыдущий месяц: Август 2023
# Пред-предыдущий месяц: Июль 2023
# Найдено проектов, завершившихся в Август 2023: 39
# Примеры значений в колонке 'month':
# 412    август 2023
# 413    август 2023
# 414    август 2023
# 415    август 2023
# 416    август 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 39
# Найдено менеджеров: 6
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 8
# Отгрузка за Август 2023: 48337047.0
# Отгрузка за Сентябрь 2023: 14245897.0
# Коэффициент пролонгации 1m: 0.29472005188897865
# Проектов, завершившихся в Июль 2023: 7
# Проектов без пролонгации в первый месяц: 5
# Отгрузка за Июль 2023 (для 2m): 21884213.0
# Отгрузка за Сентябрь 2023 (для 2m): 100000.0
# Коэффициент пролонгации 2m: 0.004569504052990162
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 10
# Отгрузка за Август 2023: 136154074.0
# Отгрузка за Сентябрь 2023: 23477400.0
# Коэффициент пролонгации 1m: 0.172432592799243
# Проектов, завершившихся в Июль 2023: 8
# Проектов без пролонгации в первый месяц: 5
# Отгрузка за Июль 2023 (для 2m): 27450000.0
# Отгрузка за Сентябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 6
# Отгрузка за Август 2023: 36537854.0
# Отгрузка за Сентябрь 2023: 27968645.0
# Коэффициент пролонгации 1m: 0.7654703803896091
# Проектов, завершившихся в Июль 2023: 5
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Июль 2023 (для 2m): 18141000.0
# Отгрузка за Сентябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 8
# Отгрузка за Август 2023: 49109500.0
# Отгрузка за Сентябрь 2023: 22314500.0
# Коэффициент пролонгации 1m: 0.4543825532738065
# Проектов, завершившихся в Июль 2023: 6
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Июль 2023 (для 2m): 12155500.0
# Отгрузка за Сентябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 1
# Отгрузка за Август 2023: 33385375.0
# Отгрузка за Сентябрь 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Июль 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 6
# Отгрузка за Август 2023: 20674000.0
# Отгрузка за Сентябрь 2023: 20644000.0
# Коэффициент пролонгации 1m: 0.9985489020025152
# Проектов, завершившихся в Июль 2023: 9
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Июль 2023 (для 2m): 16204950.0
# Отгрузка за Сентябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Анализ месяца Октябрь 2023
# Предыдущий месяц: Сентябрь 2023
# Пред-предыдущий месяц: Август 2023
# Найдено проектов, завершившихся в Сентябрь 2023: 69
# Примеры значений в колонке 'month':
# 451    сентябрь 2023
# 452    сентябрь 2023
# 453    сентябрь 2023
# 454    сентябрь 2023
# 455    сентябрь 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 69
# Найдено менеджеров: 7
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 18
# Отгрузка за Сентябрь 2023: 78682608.0
# Отгрузка за Октябрь 2023: 62444580.0
# Коэффициент пролонгации 1m: 0.7936262102547491
# Проектов, завершившихся в Август 2023: 8
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Август 2023 (для 2m): 27495000.0
# Отгрузка за Октябрь 2023 (для 2m): 16335900.0
# Коэффициент пролонгации 2m: 0.5941407528641571
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 14
# Отгрузка за Сентябрь 2023: 100871570.0
# Отгрузка за Октябрь 2023: 105636875.0
# Коэффициент пролонгации 1m: 1.0472413089238126
# Проектов, завершившихся в Август 2023: 6
# Проектов без пролонгации в первый месяц: 2
# Отгрузка за Август 2023 (для 2m): 12193000.0
# Отгрузка за Октябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 9
# Отгрузка за Сентябрь 2023: 40137000.0
# Отгрузка за Октябрь 2023: 35591500.0
# Коэффициент пролонгации 1m: 0.8867503799486758
# Проектов, завершившихся в Август 2023: 10
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Август 2023 (для 2m): 113512500.0
# Отгрузка за Октябрь 2023 (для 2m): 8202000.0
# Коэффициент пролонгации 2m: 0.07225635943178065
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 20
# Отгрузка за Сентябрь 2023: 91394222.0
# Отгрузка за Октябрь 2023: 76935500.0
# Коэффициент пролонгации 1m: 0.841798292237774
# Проектов, завершившихся в Август 2023: 8
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Август 2023 (для 2m): 32948637.0
# Отгрузка за Октябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 4
# Отгрузка за Сентябрь 2023: 66603075.0
# Отгрузка за Октябрь 2023: 29910000.0
# Коэффициент пролонгации 1m: 0.44907836462505674
# Проектов, завершившихся в Август 2023: 1
# Проектов без пролонгации в первый месяц: 1
# Отгрузка за Август 2023 (для 2m): 33385375.0
# Отгрузка за Октябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 2
# Отгрузка за Сентябрь 2023: 4395106.0
# Отгрузка за Октябрь 2023: 5751064.0
# Коэффициент пролонгации 1m: 1.3085154260215794
# Проектов, завершившихся в Август 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Иванова Мария Сергеевна
# Проектов у менеджера: 2
# Отгрузка за Сентябрь 2023: 0.0
# Отгрузка за Октябрь 2023: 0.0
# Коэффициент пролонгации 1m: 0
# Проектов, завершившихся в Август 2023: 6
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Август 2023 (для 2m): 0.0
# Отгрузка за Октябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0
#
# Анализ месяца Ноябрь 2023
# Предыдущий месяц: Октябрь 2023
# Пред-предыдущий месяц: Сентябрь 2023
# Найдено проектов, завершившихся в Октябрь 2023: 37
# Примеры значений в колонке 'month':
# 520    октябрь 2023
# 521    октябрь 2023
# 522    октябрь 2023
# 523    октябрь 2023
# 524    октябрь 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 32
# Найдено менеджеров: 4
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 15
# Отгрузка за Октябрь 2023: 27149000.0
# Отгрузка за Ноябрь 2023: 22703000.0
# Коэффициент пролонгации 1m: 0.8362370621385686
# Проектов, завершившихся в Сентябрь 2023: 14
# Проектов без пролонгации в первый месяц: 9
# Отгрузка за Сентябрь 2023 (для 2m): 20499945.0
# Отгрузка за Ноябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 12
# Отгрузка за Октябрь 2023: 57792850.0
# Отгрузка за Ноябрь 2023: 35889400.0
# Коэффициент пролонгации 1m: 0.6210006947226171
# Проектов, завершившихся в Сентябрь 2023: 9
# Проектов без пролонгации в первый месяц: 8
# Отгрузка за Сентябрь 2023 (для 2m): 21398500.0
# Отгрузка за Ноябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 3
# Отгрузка за Октябрь 2023: 16412647.0
# Отгрузка за Ноябрь 2023: 15648000.0
# Коэффициент пролонгации 1m: 0.9534111103467954
# Проектов, завершившихся в Сентябрь 2023: 2
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 2
# Отгрузка за Октябрь 2023: 25570000.0
# Отгрузка за Ноябрь 2023: 6919000.0
# Коэффициент пролонгации 1m: 0.270590535784122
# Проектов, завершившихся в Сентябрь 2023: 20
# Проектов без пролонгации в первый месяц: 8
# Отгрузка за Сентябрь 2023 (для 2m): 29214722.0
# Отгрузка за Ноябрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Анализ месяца Декабрь 2023
# Предыдущий месяц: Ноябрь 2023
# Пред-предыдущий месяц: Октябрь 2023
# Найдено проектов, завершившихся в Ноябрь 2023: 61
# Примеры значений в колонке 'month':
# 557    ноябрь 2023
# 558    ноябрь 2023
# 559    ноябрь 2023
# 560    ноябрь 2023
# 561    ноябрь 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 61
# Найдено менеджеров: 7
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 1
# Отгрузка за Ноябрь 2023: 5064000.0
# Отгрузка за Декабрь 2023: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Октябрь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 9
# Отгрузка за Ноябрь 2023: 48838191.0
# Отгрузка за Декабрь 2023: 13382234.0
# Коэффициент пролонгации 1m: 0.2740116643550536
# Проектов, завершившихся в Октябрь 2023: 5
# Проектов без пролонгации в первый месяц: 3
# Отгрузка за Октябрь 2023 (для 2m): 17110147.0
# Отгрузка за Декабрь 2023 (для 2m): 1394339.0
# Коэффициент пролонгации 2m: 0.0814919357501721
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 19
# Отгрузка за Ноябрь 2023: 55405100.0
# Отгрузка за Декабрь 2023: 20008830.0
# Коэффициент пролонгации 1m: 0.36113697114525556
# Проектов, завершившихся в Октябрь 2023: 15
# Проектов без пролонгации в первый месяц: 9
# Отгрузка за Октябрь 2023 (для 2m): 10871500.0
# Отгрузка за Декабрь 2023 (для 2m): 6810000.0
# Коэффициент пролонгации 2m: 0.6264084992871269
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 6
# Отгрузка за Ноябрь 2023: 11306000.0
# Отгрузка за Декабрь 2023: 6785000.0
# Коэффициент пролонгации 1m: 0.6001238280558995
# Проектов, завершившихся в Октябрь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 17
# Отгрузка за Ноябрь 2023: 96045000.0
# Отгрузка за Декабрь 2023: 75977500.0
# Коэффициент пролонгации 1m: 0.791061481597168
# Проектов, завершившихся в Октябрь 2023: 5
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Октябрь 2023 (для 2m): 32164500.0
# Отгрузка за Декабрь 2023 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 8
# Отгрузка за Ноябрь 2023: 16972000.0
# Отгрузка за Декабрь 2023: 5500000.0
# Коэффициент пролонгации 1m: 0.32406316285646947
# Проектов, завершившихся в Октябрь 2023: 12
# Проектов без пролонгации в первый месяц: 8
# Отгрузка за Октябрь 2023 (для 2m): 18054750.0
# Отгрузка за Декабрь 2023 (для 2m): 8754000.0
# Коэффициент пролонгации 2m: 0.48485855522784865
#
# Обработка менеджера: Петрова Анна Дмитриевна
# Проектов у менеджера: 1
# Отгрузка за Ноябрь 2023: 9849200.0
# Отгрузка за Декабрь 2023: 10944252.0
# Коэффициент пролонгации 1m: 1.1111818218738578
# Проектов, завершившихся в Октябрь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Анализ месяца Январь 2024
# Предыдущий месяц: Декабрь 2023
# Пред-предыдущий месяц: Ноябрь 2023
# Найдено проектов, завершившихся в Декабрь 2023: 107
# Примеры значений в колонке 'month':
# 618    декабрь 2023
# 619    декабрь 2023
# 620    декабрь 2023
# 621    декабрь 2023
# 622    декабрь 2023
# Name: month, dtype: object
# Проектов после исключения 'стоп' и 'end': 107
# Найдено менеджеров: 8
#
# Обработка менеджера: Кузнецов Михаил Иванович
# Проектов у менеджера: 14
# Отгрузка за Декабрь 2023: 62374606.0
# Отгрузка за Январь 2024: 36725000.0
# Коэффициент пролонгации 1m: 0.5887812742256039
# Проектов, завершившихся в Ноябрь 2023: 9
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Ноябрь 2023 (для 2m): 35989606.0
# Отгрузка за Январь 2024 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Васильев Артем Александрович
# Проектов у менеджера: 25
# Отгрузка за Декабрь 2023: 293891696.0
# Отгрузка за Январь 2024: 157352079.0
# Коэффициент пролонгации 1m: 0.5354083873128556
# Проектов, завершившихся в Ноябрь 2023: 8
# Проектов без пролонгации в первый месяц: 7
# Отгрузка за Ноябрь 2023 (для 2m): 10872000.0
# Отгрузка за Январь 2024 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Федорова Марина Васильевна
# Проектов у менеджера: 2
# Отгрузка за Декабрь 2023: 5025000.0
# Отгрузка за Январь 2024: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Ноябрь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Обработка менеджера: Смирнова Ольга Владимировна
# Проектов у менеджера: 25
# Отгрузка за Декабрь 2023: 140440880.0
# Отгрузка за Январь 2024: 57170180.0
# Коэффициент пролонгации 1m: 0.4070764865614627
# Проектов, завершившихся в Ноябрь 2023: 19
# Проектов без пролонгации в первый месяц: 14
# Отгрузка за Ноябрь 2023 (для 2m): 25441600.0
# Отгрузка за Январь 2024 (для 2m): 4517550.0
# Коэффициент пролонгации 2m: 0.17756548330293692
#
# Обработка менеджера: Попова Екатерина Николаевна
# Проектов у менеджера: 24
# Отгрузка за Декабрь 2023: 155893382.0
# Отгрузка за Январь 2024: 67175500.0
# Коэффициент пролонгации 1m: 0.4309066821066208
# Проектов, завершившихся в Ноябрь 2023: 6
# Проектов без пролонгации в первый месяц: 4
# Отгрузка за Ноябрь 2023 (для 2m): 4520500.0
# Отгрузка за Январь 2024 (для 2m): 4105000.0
# Коэффициент пролонгации 2m: 0.9080853887844265
#
# Обработка менеджера: Соколова Анастасия Викторовна
# Проектов у менеджера: 15
# Отгрузка за Декабрь 2023: 87886621.0
# Отгрузка за Январь 2024: 34697500.0
# Коэффициент пролонгации 1m: 0.3947984301273797
# Проектов, завершившихся в Ноябрь 2023: 17
# Проектов без пролонгации в первый месяц: 9
# Отгрузка за Ноябрь 2023 (для 2m): 10307000.0
# Отгрузка за Январь 2024 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: Михайлов Андрей Сергеевич
# Проектов у менеджера: 1
# Отгрузка за Декабрь 2023: 13241000.0
# Отгрузка за Январь 2024: 0.0
# Коэффициент пролонгации 1m: 0.0
# Проектов, завершившихся в Ноябрь 2023: 1
# Проектов без пролонгации в первый месяц: 1
# Отгрузка за Ноябрь 2023 (для 2m): 5064000.0
# Отгрузка за Январь 2024 (для 2m): 0.0
# Коэффициент пролонгации 2m: 0.0
#
# Обработка менеджера: без А/М
# Проектов у менеджера: 1
# Отгрузка за Декабрь 2023: 0.0
# Отгрузка за Январь 2024: 0.0
# Коэффициент пролонгации 1m: 0
# Проектов, завершившихся в Ноябрь 2023: 0
# Проектов без пролонгации в первый месяц: 0
#
# Анализ месяца Февраль 2024
# Предыдущий месяц: Январь 2024
# Пред-предыдущий месяц: Декабрь 2023
# Найдено проектов, завершившихся в Январь 2024: 0
# Пропускаем Февраль 2024 - нет завершенных проектов в Январь 2024
#
# Результаты расчета:
#           Месяц                       Менеджер  Коэф. пролонгации (1m)  \
# 0  Декабрь 2022   Васильев Артем Александрович                    0.42
# 1  Декабрь 2022      Михайлов Андрей Сергеевич                    0.91
# 2  Декабрь 2022  Соколова Анастасия Викторовна                    0.84
# 3  Декабрь 2022        Иванова Мария Сергеевна                    0.00
# 4  Декабрь 2022    Попова Екатерина Николаевна                    0.30
#
#    Коэф. пролонгации (2m)  Отгрузка последнего месяца  \
# 0                     0.0                  62507900.0
# 1                     0.0                  85920500.0
# 2                     0.0                  22443500.0
# 3                     0.0                   5224000.0
# 4                     0.0                  13802000.0
#
#    Отгрузка текущего месяца
# 0                26199500.0
# 1                77866000.0
# 2                18752000.0
# 3                       0.0
# 4                 4083000.0
# Начинаем создание отчета...
# Excel writer создан
# Создаем визуализации...
# Начинаем создание визуализаций...
# Графики созданы, сохраняем в Excel...
# Лист 'Графики' создан
# Изображение добавлено на лист
# Размеры ячеек настроены
# Сохраняем основной отчет...
# Создаем сводный отчет...
# Применяем форматирование...
# Отчет сохранен как отчет_пролонгации.xlsx
